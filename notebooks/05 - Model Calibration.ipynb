# %% [markdown]
# # Model Calibration
#
# > Block 1 - Validation and Evaluation Protocol
#
# A model can rank perfectly and still produce probabilities you must never act on.

# %% [markdown]
# ## 1. Discrimination vs Calibration
#
# - High AUC with useless probabilities: a worked example
# - When calibration matters and when ranking is enough

# %% [markdown]
# ## 2. Reliability Diagrams
#
# - Uniform vs quantile binning
# - Sensitivity to the number of bins
# - Confidence bands and small-sample noise

# %% [markdown]
# ## 3. Calibration Metrics
#
# - ECE, MCE, ACE and their bin dependence
# - Brier score decomposition: reliability, resolution, uncertainty
# - Log loss as a calibration-sensitive metric

# %% [markdown]
# ## 4. Why Models Become Miscalibrated
#
# - Boosting, SVM and Naive Bayes characteristic distortions
# - Regularization and tree depth effects
# - Class weights and resampling shifting the probability scale

# %% [markdown]
# ## 5. Post-hoc Calibration Methods
#
# - Platt scaling (sigmoid)
# - Isotonic regression and its data requirements
# - Beta calibration
# - Temperature scaling

# %% [markdown]
# ## 6. CalibratedClassifierCV Done Right
#
# - Where calibration belongs in the pipeline
# - Data splitting: prefit vs cross-validated calibration
# - Calibrating inside an outer cross validation loop

# %% [markdown]
# ## 7. Calibration Under Imbalance and Prior Shift
#
# - Prevalence correction of predicted probabilities
# - Recovering calibration after resampling

# %% [markdown]
# ## 8. Multiclass Calibration
#
# - One-vs-rest calibration and normalization
# - Confidence calibration vs full calibration

# %% [markdown]
# ## 9. Does Calibration Cost Discrimination?
#
# - Measuring AUC before and after calibration
# - Monotone transforms and rank preservation

# %% [markdown]
# ## 10. Calibration Decay Over Time
#
# - Recalibration as a cheap alternative to retraining
# - Bridge to notebook 11

# %% [markdown]
# ## 11. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
