# %% [markdown]
# # Time Series Feature Engineering
#
# > Block 2 - Time and Streaming Data
#
# Building temporal features that are both informative and safe to serve.

# %% [markdown]
# ## 1. Reframing Forecasting as Supervised Learning
#
# - The lag matrix construction
# - Prediction origin, horizon and feature cut-off

# %% [markdown]
# ## 2. Lag Features and the shift Discipline
#
# - Choosing lags from autocorrelation structure
# - Per-group shifting in panel data

# %% [markdown]
# ## 3. Rolling and Expanding Statistics
#
# - Closed windows and the off-by-one leak
# - Exponentially weighted statistics
# - Rolling quantiles, volatility and counts

# %% [markdown]
# ## 4. Calendar, Holiday and Fourier Features
#
# - Cyclical encoding of time components
# - Fourier terms for multiple seasonalities
# - Holiday and event calendars

# %% [markdown]
# ## 5. Differencing, Stationarity and Detrending
#
# - Why tree models cannot extrapolate a trend
# - Target transformation and inverse transformation

# %% [markdown]
# ## 6. Temporal Target Encoding and Group Statistics
#
# - Expanding-window target statistics
# - Cold start for new entities

# %% [markdown]
# ## 7. Exogenous Variables and Availability at Prediction Time
#
# - Known-in-advance vs observed-only covariates
# - Data latency and the real feature cut-off

# %% [markdown]
# ## 8. Direct vs Recursive Multi-Step Strategies
#
# - One model per horizon vs iterated one-step-ahead
# - Error accumulation in recursive forecasting

# %% [markdown]
# ## 9. Feature Pipelines That Are Safe to Serve
#
# - Point-in-time correctness
# - Reusing the same transform code in training and serving

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
