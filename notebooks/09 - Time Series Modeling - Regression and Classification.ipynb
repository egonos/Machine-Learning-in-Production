# %% [markdown]
# # Time Series Modeling: Regression and Classification
#
# > Block 2 - Time and Streaming Data
#
# Forecasting values, predicting events, and classifying whole series.

# %% [markdown]
# ## 1. Problem Framing
#
# - Forecasting vs event prediction vs series classification
# - Choosing the unit of observation

# %% [markdown]
# ## 2. Classical Baselines
#
# - Naive and seasonal naive
# - Exponential smoothing (ETS)
# - ARIMA / SARIMAX as a reference point

# %% [markdown]
# ## 3. Gradient Boosting for Forecasting
#
# - Global models across many series vs one model per series
# - Handling trend, seasonality and level shifts

# %% [markdown]
# ## 4. Panel and Hierarchical Data
#
# - Series-level features and entity embeddings
# - Hierarchical reconciliation of forecasts
# - Cold start and short histories

# %% [markdown]
# ## 5. Label Design for Temporal Classification
#
# - Observation window vs performance window
# - Censoring and the survival-analysis alternative
# - Event rate stability across time

# %% [markdown]
# ## 6. Time Series Classification (Series as Sample)
#
# - Summary-feature approaches
# - MiniRocket and random convolutional kernels
# - Shapelets and interval-based methods
# - DTW and distance-based classifiers

# %% [markdown]
# ## 7. Quantile Regression and Prediction Intervals
#
# - Pinball loss in gradient boosting
# - Quantile crossing and how to handle it

# %% [markdown]
# ## 8. Evaluating Across Horizons
#
# - Error growth as a function of horizon
# - Aggregating across series: weighting and scale

# %% [markdown]
# ## 9. Model Selection for Temporal Problems
#
# - Combining notebook 07 splits with notebook 06 comparisons

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
