# %% [markdown]
# # Time Series Validation: Sliding vs Expanding Windows
#
# > Block 2 - Time and Streaming Data
#
# Cross validation for data where the future must never inform the past.

# %% [markdown]
# ## 1. Why Random K-Fold Fails on Temporal Data
#
# - Autocorrelation makes interpolation trivial
# - Demo: random K-Fold vs forward chaining on the same series

# %% [markdown]
# ## 2. Forward-Chaining Validation
#
# - TimeSeriesSplit mechanics and parameters
# - Train size, test size and number of folds

# %% [markdown]
# ## 3. Expanding (Anchored) Windows
#
# - When more history keeps helping
# - Growing training cost and stale regimes

# %% [markdown]
# ## 4. Sliding (Rolling) Windows
#
# - Deliberate forgetting under regime change
# - Comparing the two schemes on drifting and stable processes

# %% [markdown]
# ## 5. Window Length Is a Hyperparameter
#
# - Tuning the lookback without leaking
# - Interaction with retraining frequency

# %% [markdown]
# ## 6. Gaps, Purging and Embargo
#
# - Overlapping label horizons
# - Purged K-Fold and the embargo period
# - Combinatorial purged cross validation

# %% [markdown]
# ## 7. Backtesting Protocol
#
# - Refit frequency: every step, every N steps, never
# - Walk-forward evaluation
# - Horizon-aware scoring
# - Simulating the real deployment timeline

# %% [markdown]
# ## 8. Panel Data: Temporal vs New-Entity Generalization
#
# - Two different deployment questions, two different splits
# - Grouped time series splitting

# %% [markdown]
# ## 9. Visualizing Split Schemes
#
# - Plotting train/test/gap regions per fold

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
