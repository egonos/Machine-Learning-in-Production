# %% [markdown]
# # From Notebook to Production
#
# > Block 5 - The Production Loop
#
# Turning an experiment into a reproducible, testable, servable artifact.

# %% [markdown]
# ## 1. The Notebook-to-Service Gap
#
# - What breaks first when a notebook meets a scheduler

# %% [markdown]
# ## 2. Packaging the Full Pipeline
#
# - Preprocessing must live inside the artifact
# - Serialization, versioning and backward compatibility
# - Custom transformers and import-path fragility

# %% [markdown]
# ## 3. Reproducibility
#
# - Seeds and sources of non-determinism
# - Data versioning and snapshots
# - Environment pinning

# %% [markdown]
# ## 4. Training/Serving Skew and Feature Stores
#
# - Point-in-time correct feature retrieval
# - One definition, two execution paths

# %% [markdown]
# ## 5. Data Contracts and Validation
#
# - Schema, range, nullability and cardinality checks
# - pandera / Great Expectations in the pipeline
# - Failing loudly vs degrading gracefully

# %% [markdown]
# ## 6. Experiment Tracking and Model Registry
#
# - MLflow runs, params, metrics, artifacts
# - Promotion stages and approval gates

# %% [markdown]
# ## 7. Testing Machine Learning Code
#
# - Unit tests for transforms, splitters and metrics
# - Behavioural and invariance tests for models
# - Golden datasets and regression tests

# %% [markdown]
# ## 8. Model Documentation
#
# - Model cards: intended use, assumptions, known failure modes
# - Recording the validation protocol itself

# %% [markdown]
# ## 9. Batch vs Real-Time Serving
#
# - Latency budgets and feature availability
# - Caching and precomputation

# %% [markdown]
# ## 10. Deployment Checklist

# %% [markdown]
# ## Key Takeaways
