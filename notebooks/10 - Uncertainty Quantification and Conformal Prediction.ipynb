# %% [markdown]
# # Uncertainty Quantification and Conformal Prediction
#
# > Block 2 - Time and Streaming Data
#
# Distribution-free prediction intervals and sets with finite-sample coverage guarantees.

# %% [markdown]
# ## 1. Types of Uncertainty
#
# - Aleatoric vs epistemic uncertainty
# - Why point predictions are insufficient in production

# %% [markdown]
# ## 2. Split Conformal Prediction
#
# - Exchangeability and the coverage guarantee
# - Nonconformity scores and the calibration set
# - The guarantee is marginal, not conditional

# %% [markdown]
# ## 3. Conformal Regression
#
# - Absolute residual scores
# - Normalized / locally adaptive scores
# - Conformalized quantile regression (CQR)

# %% [markdown]
# ## 4. Conformal Classification
#
# - Prediction sets instead of single labels
# - Adaptive prediction sets (APS, RAPS)
# - Class-conditional coverage

# %% [markdown]
# ## 5. Coverage vs Efficiency
#
# - Empirical coverage checks
# - Interval width and set size as efficiency measures
# - Conditional coverage diagnostics by segment

# %% [markdown]
# ## 6. Cross-Conformal and Jackknife+
#
# - Using all data for both fitting and calibration
# - Computational cost trade-offs

# %% [markdown]
# ## 7. Conformal Under Distribution Shift
#
# - Weighted conformal prediction for covariate shift
# - Adaptive conformal inference (ACI) for time series
# - Bridge to notebook 11

# %% [markdown]
# ## 8. Conformal vs Calibration vs Bayesian Approaches
#
# - What each method guarantees and what it does not
# - Combining calibrated probabilities with conformal sets

# %% [markdown]
# ## 9. Using Uncertainty in Decisions
#
# - Selective prediction and abstention
# - Routing uncertain cases to human review
# - Risk-controlling prediction sets

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
