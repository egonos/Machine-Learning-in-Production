# %% [markdown]
# # Feature Selection and Elimination
#
# > Block 4 - Feature Selection and Tuning
#
# The goal determines the method, and the CV loop determines whether the result is honest.

# %% [markdown]
# ## 1. Why Select? Goal Drives Method
#
# - Performance, latency, data cost, stability, interpretability
# - When selection actively hurts

# %% [markdown]
# ## 2. Filter Methods
#
# - Variance threshold, correlation, ANOVA F-test
# - Mutual information for non-linear dependence
# - Speed vs blindness to interactions

# %% [markdown]
# ## 3. Multicollinearity
#
# - VIF and condition number
# - Hierarchical clustering of correlated features
# - Picking a representative per cluster

# %% [markdown]
# ## 4. Redundancy-Aware Selection: mRMR
#
# - Relevance minus redundancy
# - Practical implementations

# %% [markdown]
# ## 5. Wrapper Methods
#
# - Recursive feature elimination (RFE) and RFECV
# - Sequential forward and backward selection
# - Computational cost and greedy-search traps

# %% [markdown]
# ## 6. Embedded Methods
#
# - L1 and Elastic Net paths
# - Tree-based importances and LightGBM
# - Regularization as implicit selection

# %% [markdown]
# ## 7. Null Importance / Target Permutation
#
# - Building the null distribution of importance
# - Thresholding against noise features

# %% [markdown]
# ## 8. Boruta and BorutaSHAP
#
# - Shadow features and the all-relevant formulation
# - All-relevant vs minimal-optimal selection

# %% [markdown]
# ## 9. SHAP-Based Elimination
#
# - Recursive elimination driven by SHAP
# - Cost and stability considerations

# %% [markdown]
# ## 10. Stability Selection
#
# - Selection frequency across bootstrap samples
# - If the selected set changes with the seed, the signal is weak

# %% [markdown]
# ## 11. The Cardinal Sin: Selecting Outside the CV Loop
#
# - Measuring the optimistic bias with a pure-noise dataset
# - Correct nesting of selection inside cross validation

# %% [markdown]
# ## 12. Selecting Features That Survive Drift
#
# - Temporal stability of features
# - Trading a little accuracy for a lot of robustness

# %% [markdown]
# ## 13. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
