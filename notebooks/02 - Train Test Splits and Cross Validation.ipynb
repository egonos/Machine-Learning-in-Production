# %% [markdown]
# # Train/Test Splits and Cross Validation
#
# > Block 1 - Validation and Evaluation Protocol
#
# Designing a validation protocol that estimates the quantity you actually care about.

# %% [markdown]
# ## 1. Why a Single Hold-Out Split Is Not Enough
#
# - The same data, 100 different splits, 100 different scores
# - Variance of the hold-out estimate as a function of test size
# - The bias-variance trade-off of the estimator itself

# %% [markdown]
# ## 2. K-Fold Cross Validation
#
# - Mechanics and the role of k
# - Leave-One-Out: low bias, high variance, high cost
# - cross_val_score vs cross_validate vs cross_val_predict

# %% [markdown]
# ## 3. Stratification
#
# - StratifiedKFold and rare classes
# - Stratified splitting for regression via target binning
# - Multi-label and multi-output stratification

# %% [markdown]
# ## 4. Grouped Data: GroupKFold and StratifiedGroupKFold
#
# - Repeated entities: customers, patients, devices, sessions
# - The most common silent validation error
# - Choosing the grouping key from the deployment question

# %% [markdown]
# ## 5. Repeated CV and the Uncertainty of a CV Score
#
# - RepeatedKFold and RepeatedStratifiedKFold
# - Standard error of the mean CV score
# - The one-standard-error rule for model selection

# %% [markdown]
# ## 6. Nested Cross Validation
#
# - Why model selection and performance estimation cannot share a loop
# - Inner loop for tuning, outer loop for estimation
# - Cost and when a simpler protocol is defensible

# %% [markdown]
# ## 7. Overfitting the Validation Set
#
# - Multiplicity: every decision spends validation signal
# - Selection bias in leaderboards
# - Hold-out hygiene: the untouched final test set

# %% [markdown]
# ## 8. Writing and Visualizing Custom Splitters
#
# - The scikit-learn splitter API
# - Plotting split schemes to verify them visually

# %% [markdown]
# ## 9. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
