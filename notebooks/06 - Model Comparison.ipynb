# %% [markdown]
# # Model Comparison
#
# > Block 1 - Validation and Evaluation Protocol
#
# Deciding whether one model is genuinely better than another, or just luckier.

# %% [markdown]
# ## 1. What Does a 0.003 AUC Difference Mean?
#
# - Establishing the noise floor of a comparison
# - Simulating two identical models to see the spread

# %% [markdown]
# ## 2. Sources of Variance
#
# - Data sampling, split randomness, model randomness
# - Separating them with repeated experiments

# %% [markdown]
# ## 3. Why Naive Paired t-Tests Fail on CV Scores
#
# - Overlapping training sets break independence
# - Inflated Type I error rates

# %% [markdown]
# ## 4. Corrected Tests for Cross-Validated Scores
#
# - Nadeau-Bengio corrected resampled t-test
# - 5x2cv paired t-test
# - Bayesian alternatives to null hypothesis testing

# %% [markdown]
# ## 5. McNemar's Test
#
# - Paired predictions on a single test set
# - When it is the right tool

# %% [markdown]
# ## 6. Bootstrap Confidence Intervals for Metric Differences
#
# - Paired bootstrap on the test set
# - Reporting intervals instead of point estimates

# %% [markdown]
# ## 7. Comparing Many Models on Many Datasets
#
# - Friedman test and Nemenyi post-hoc
# - Critical difference diagrams

# %% [markdown]
# ## 8. Multiple Comparisons and the Winner's Curse
#
# - Correcting for the number of candidates
# - Why the winning model's CV score is optimistic

# %% [markdown]
# ## 9. Beyond Accuracy
#
# - Latency, memory, serving cost
# - Complexity, maintainability, explainability requirements
# - Multi-criteria decision making

# %% [markdown]
# ## 10. Practical vs Statistical Significance
#
# - Translating a metric delta into business value
# - Minimum detectable effect and required sample size

# %% [markdown]
# ## 11. Comparison Report Template

# %% [markdown]
# ## Key Takeaways
