# %% [markdown]
# # Partial Dependence, ICE and ALE
#
# > Block 3 - Explainability
#
# Visualizing how a model responds to a feature, and why the standard plot can lie.

# %% [markdown]
# ## 1. Partial Dependence: Definition and Estimation
#
# - Marginalizing over the complement features
# - Monte Carlo estimation and grid resolution

# %% [markdown]
# ## 2. The Extrapolation Problem
#
# - Correlated features produce impossible synthetic points
# - Demo: PDP on strongly correlated predictors

# %% [markdown]
# ## 3. Individual Conditional Expectation (ICE)
#
# - Per-observation curves reveal heterogeneity
# - Centered ICE (c-ICE)
# - When the average curve hides opposite effects

# %% [markdown]
# ## 4. Accumulated Local Effects (ALE)
#
# - Local differences inside conditional intervals
# - Why ALE avoids the extrapolation problem
# - Interpretation of the ALE scale

# %% [markdown]
# ## 5. PDP vs ALE vs Marginal Plots
#
# - Side-by-side comparison on the same data
# - A decision rule for which to present

# %% [markdown]
# ## 6. Two-Way Dependence and Interactions
#
# - 2D PDP and 2D ALE
# - Friedman's H-statistic
# - Interaction detection cost

# %% [markdown]
# ## 7. Categorical Features and Monotonic Constraints
#
# - Ordering categories for ALE
# - Enforcing monotonicity and what it buys you

# %% [markdown]
# ## 8. Uncertainty in Dependence Plots
#
# - Bootstrap bands
# - Sparse regions of the feature space

# %% [markdown]
# ## 9. Common Misinterpretations
#
# - Model behaviour is not the data generating process
# - Dependence plots are not causal effects

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
