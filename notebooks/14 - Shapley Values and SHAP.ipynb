# %% [markdown]
# # Shapley Values and SHAP
#
# > Block 3 - Explainability
#
# A fair allocation from game theory, its algorithms, and the claims it does not support.

# %% [markdown]
# ## 1. Game-Theoretic Origin
#
# - Coalitions, marginal contributions and the value function
# - From cooperative games to feature attribution

# %% [markdown]
# ## 2. The Shapley Axioms
#
# - Efficiency, symmetry, dummy, additivity
# - Uniqueness and what it actually guarantees

# %% [markdown]
# ## 3. The Computational Problem
#
# - 2^n coalitions and why exact computation is hopeless
# - Sampling-based approximation

# %% [markdown]
# ## 4. Estimation Algorithms
#
# - KernelSHAP and the weighted linear regression trick
# - TreeSHAP for tree ensembles
# - LinearSHAP and DeepSHAP
# - Runtime and accuracy trade-offs

# %% [markdown]
# ## 5. Interventional vs Observational SHAP
#
# - Marginal vs conditional expectations
# - The feature_perturbation parameter and how it changes conclusions
# - Which one answers which question

# %% [markdown]
# ## 6. The Background / Baseline Set
#
# - The explanation is always relative to a reference
# - Choosing and sizing the background data
# - Segment-specific baselines

# %% [markdown]
# ## 7. Local Explanations
#
# - Waterfall and force plots
# - Explaining a single decision to a stakeholder

# %% [markdown]
# ## 8. Global Views From Local Explanations
#
# - Beeswarm summary plots
# - Mean absolute SHAP as importance and its limits
# - Comparison with permutation importance

# %% [markdown]
# ## 9. Dependence Plots and Interaction Values
#
# - SHAP dependence vs PDP
# - SHAP interaction values and their cost

# %% [markdown]
# ## 10. SHAP for Model Debugging and Leakage Detection
#
# - A single feature dominating every explanation
# - Explanations that contradict domain knowledge

# %% [markdown]
# ## 11. SHAP for Drift Attribution and Segment Analysis
#
# - Comparing SHAP distributions across time periods
# - Explaining the domain classifier

# %% [markdown]
# ## 12. SHAP Is Not Causal
#
# - Credit splitting between correlated features
# - Fair attribution is not true effect
# - Common misuses in business communication

# %% [markdown]
# ## 13. SHAP vs PDP vs Permutation Importance
#
# - A comparison table and when to use each

# %% [markdown]
# ## 14. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
