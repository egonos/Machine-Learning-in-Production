# %% [markdown]
# # Model Evaluation
#
# > Block 1 - Validation and Evaluation Protocol
#
# From business cost to a metric you can defend, and to a decision threshold you can ship.

# %% [markdown]
# ## 1. From Business Cost to Metric
#
# - The cost matrix and expected utility
# - Deriving the metric from the decision it supports
# - When no single metric is enough

# %% [markdown]
# ## 2. Classification Metrics
#
# - The accuracy paradox under imbalance
# - Precision, recall, F-beta
# - Matthews correlation coefficient and Cohen's kappa
# - Confusion matrix reading discipline

# %% [markdown]
# ## 3. ROC-AUC vs Precision-Recall AUC
#
# - What each curve holds constant
# - Prevalence dependence and why PR-AUC is preferred under imbalance
# - Average precision vs interpolated AUC-PR

# %% [markdown]
# ## 4. Decision Thresholds
#
# - The threshold is a business decision, not a default of 0.5
# - Cost-sensitive threshold optimization
# - TunedThresholdClassifierCV and threshold selection inside CV
# - Threshold stability over time

# %% [markdown]
# ## 5. Ranking and Business Metrics
#
# - Lift and gain curves, decile analysis
# - Precision@k and recall@k under capacity constraints
# - Gini coefficient and its relation to AUC

# %% [markdown]
# ## 6. Regression Metrics
#
# - RMSE, MAE, MAPE, sMAPE and their failure modes
# - Pinball loss for quantile targets
# - R-squared pitfalls and baseline dependence
# - Heteroscedasticity and scale-dependent errors

# %% [markdown]
# ## 7. Proper Scoring Rules
#
# - Log loss and Brier score
# - Why improper metrics reward dishonest probabilities
# - Bridge to notebook 05

# %% [markdown]
# ## 8. Class Imbalance
#
# - Resampling vs class weights vs threshold tuning
# - Why resampling distorts predicted probabilities
# - When imbalance is not actually the problem

# %% [markdown]
# ## 9. Slice and Segment Analysis
#
# - Aggregate metrics hide subgroup failures
# - Building a slice report
# - Fairness metrics as a special case of slicing

# %% [markdown]
# ## 10. Error Analysis Workflow
#
# - Reading the worst errors
# - Clustering residuals to find systematic failure
# - From error analysis to the next feature

# %% [markdown]
# ## 11. Learning Curves
#
# - More data or more capacity?
# - Sample size planning

# %% [markdown]
# ## 12. Evaluation Report Template

# %% [markdown]
# ## Key Takeaways
