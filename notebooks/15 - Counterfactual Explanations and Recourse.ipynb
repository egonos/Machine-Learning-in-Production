# %% [markdown]
# # Counterfactual Explanations and Recourse
#
# > Block 3 - Explainability
#
# Moving from *why was I rejected* to *what would I have to change*.

# %% [markdown]
# ## 1. From Attribution to Action
#
# - Why attribution answers the wrong question for an affected user

# %% [markdown]
# ## 2. Counterfactual Explanations
#
# - Definition and desiderata: validity, proximity, sparsity, plausibility, diversity
# - The nearest counterfactual problem

# %% [markdown]
# ## 3. Generating Counterfactuals
#
# - Optimization-based search (DiCE)
# - Prototype and instance-guided methods
# - Genetic and random search variants

# %% [markdown]
# ## 4. Actionability Constraints
#
# - Immutable features (age, birthplace)
# - Monotonic and feasible-range constraints
# - Cost-weighted changes

# %% [markdown]
# ## 5. Anchors and Rule-Based Local Explanations
#
# - High-precision if-then explanations
# - Coverage vs precision trade-off

# %% [markdown]
# ## 6. Algorithmic Recourse and Robustness
#
# - Recourse invalidated by model updates
# - Gaming and strategic behaviour

# %% [markdown]
# ## 7. Communicating Explanations to Non-Technical Stakeholders
#
# - Translating model output into a narrative
# - What not to promise

# %% [markdown]
# ## 8. Regulatory and Documentation Context
#
# - Right to explanation and adverse action notices
# - Model cards and explanation records

# %% [markdown]
# ## 9. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
