# %% [markdown]
# # Hyperparameter Tuning and Model Selection
#
# > Block 4 - Feature Selection and Tuning
#
# Searching efficiently without quietly overfitting the validation set.

# %% [markdown]
# ## 1. Search Strategies
#
# - Grid vs random search and why random usually wins
# - Bayesian optimization with Optuna
# - Successive halving and Hyperband

# %% [markdown]
# ## 2. Designing the Search Space
#
# - Log scales, priors and conditional parameters
# - Reading the search history to refine the space

# %% [markdown]
# ## 3. Early Stopping Done Correctly
#
# - The validation set must live inside the fold
# - Early stopping as an implicit hyperparameter

# %% [markdown]
# ## 4. Overfitting the Validation Set During Tuning
#
# - The optimistic bias of the best observed score
# - Trial count and effective multiple testing

# %% [markdown]
# ## 5. Nested CV for Honest Estimates
#
# - Inner tuning loop, outer estimation loop
# - Interpreting variability of the selected hyperparameters

# %% [markdown]
# ## 6. Ordering the Pipeline
#
# - Preprocessing, selection, tuning, calibration, thresholding
# - Which steps belong inside which loop

# %% [markdown]
# ## 7. Budget, Parallelism and Reproducibility
#
# - Seeding, resumable studies, distributed trials

# %% [markdown]
# ## 8. Tuning for the Right Objective
#
# - Custom scorers and business metrics
# - Multi-objective tuning and Pareto fronts

# %% [markdown]
# ## 9. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
