# %% [markdown]
# # Capstone: End-to-End Case Study
#
# > Block 5 - The Production Loop
#
# Every module applied once, in order, on a single realistic problem.

# %% [markdown]
# ## 1. Problem Framing and Success Criteria
#
# - The decision, the cost matrix, the constraints

# %% [markdown]
# ## 2. Data Understanding and Leakage Audit

# %% [markdown]
# ## 3. Temporal Validation Design

# %% [markdown]
# ## 4. Baselines

# %% [markdown]
# ## 5. Feature Engineering and Selection

# %% [markdown]
# ## 6. Model Development and Tuning

# %% [markdown]
# ## 7. Calibration and Threshold Selection

# %% [markdown]
# ## 8. Uncertainty Quantification

# %% [markdown]
# ## 9. Model Comparison and Final Selection

# %% [markdown]
# ## 10. Explainability Report

# %% [markdown]
# ## 11. Drift and Monitoring Plan

# %% [markdown]
# ## 12. Deployment Package and Model Card

# %% [markdown]
# ## 13. Retrospective: What Would Break First?

# %% [markdown]
# ## Key Takeaways
