# %% [markdown]
# # Explainability Foundations and Feature Importance
#
# > Block 3 - Explainability
#
# What an explanation is for, and why the default importance plot is usually wrong.

# %% [markdown]
# ## 1. Why Explain? Audience Drives the Method
#
# - Regulator, data scientist, domain expert, end user
# - Debugging, trust, compliance, actionability

# %% [markdown]
# ## 2. A Taxonomy of Explanation Methods
#
# - Global vs local
# - Intrinsic vs post-hoc
# - Model-specific vs model-agnostic

# %% [markdown]
# ## 3. Intrinsically Interpretable Models
#
# - GLM and regularized linear models
# - Generalized additive models and Explainable Boosting Machines
# - Rule lists and decision sets
# - The overstated accuracy-interpretability trade-off

# %% [markdown]
# ## 4. Impurity-Based Importance Is Broken
#
# - Cardinality and scale bias
# - Demo: a pure-noise feature ranked highly
# - Why it is still the default in most libraries

# %% [markdown]
# ## 5. Permutation Importance
#
# - Definition and implementation
# - Train set vs test set importance: different questions
# - Repeats, variance and significance

# %% [markdown]
# ## 6. Permutation Importance With Correlated Features
#
# - Splitting credit between correlated predictors
# - Evaluating unrealistic data points
# - Grouped permutation and feature clustering

# %% [markdown]
# ## 7. Drop-Column Importance
#
# - The honest but expensive baseline
# - Retraining variance

# %% [markdown]
# ## 8. Global Surrogate Models
#
# - Fitting an interpretable model to the black box
# - Measuring fidelity and its limits

# %% [markdown]
# ## 9. Choosing an Explanation Method
#
# - A decision guide for the rest of this block

# %% [markdown]
# ## 10. Pitfalls and Checklist

# %% [markdown]
# ## Key Takeaways
